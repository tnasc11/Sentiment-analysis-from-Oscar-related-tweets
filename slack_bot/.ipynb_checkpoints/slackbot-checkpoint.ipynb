# %%
import pyjokes
import requests

webhook_url = "https://hooks.slack.com/services/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"

joke = pyjokes.get_joke()

requests.post(url=webhook_url, json = data)
# Out:
# <Response [200]>

# %%
import sqlalchemy
from sqlalchemy import create_engine

# %%
PG = create_engine("postgresql://postgres:1234@localhost:5555/twitter", echo=True)
print(3)
# Out:
# 3

# %%
import psycopg2
query = PG.execute("""SELECT * FROM tweets;""")
# Out:
# 2022-10-07 12:38:11,631 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2022-10-07 12:38:11,632 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-07 12:38:11,640 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-10-07 12:38:11,643 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-07 12:38:11,661 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-10-07 12:38:11,666 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-10-07 12:38:11,679 INFO sqlalchemy.engine.Engine SELECT * FROM tweets;
# 2022-10-07 12:38:11,681 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
mytweets = query.all()
mytweets
# Out:
# [('Spread love wherever you go!🙏💗💕\n@TomCruise \n#tomcruise \n#Oscars2023\n#OscarsForTomCruise \n#marisolbrasil https://t.co/Tv3GexglGg', Decimal('0.9402')),
#  ('Will Oscar Voters Even Consider Voting for Will Smith for ‘Emancipation’? “We Have to Allow People to Grow,” “No Chance,” “F*** Him” https://t.co/Tq4fTWrIhQ #willsmith #Oscars2023 https://t.co/PswcHL2yuU', Decimal('0.2263')),
#  ('BOLIVIA : Bolivia selects Sundance winner ‘Utama’ as Oscar submission #Utama #Oscars2023 https://t.co/5Qlg92QqDd https://t.co/9smEYrTt0N', Decimal('0.5859')),
#  ('#WillSmith #Emancipation  #Oscars2023 \nAfter the Slap, Is Will Smith Allowed to Be Oscar Nominated for ‘Emancipation’? https://t.co/25tC9mmTIl via @variety', Decimal('0.1531')),
#  ("If Will Smith doesn't win an Oscar for this role it will be a slap in the face. #Oscars2023 #Emancipation #bitchslap #slapintheface \nhttps://t.co/oGWjcnHRzG", Decimal('-0.3553')),
# ...

# %%
for tweet in mytweets[0:10]:
    twtext = tweet[0]
    compound_score = tweet[1]
    data = {'text' : f'tweet:{twtext} compound_score:{compound_score}'}
    requests.post(url=webhook_url, json = data)

# %%
type(mytweets)
# Out:
# list

# %%
import pandas as pd
df = pd.DataFrame(mytweets) 
df['sentiment']
# Out:
#                                                    text sentiment
# 0     Spread love wherever you go!🙏💗💕\n@TomCruise \n...    0.9402
# 1     Will Oscar Voters Even Consider Voting for Wil...    0.2263
# 2     BOLIVIA : Bolivia selects Sundance winner ‘Uta...    0.5859
# 3     #WillSmith #Emancipation  #Oscars2023 \nAfter ...    0.1531
# 4     If Will Smith doesn't win an Oscar for this ro...   -0.3553
# ...                                                 ...       ...
# 6875  Day1675/Reason#1675 I’d be great at the Oscars...    0.8689
# 6876  Our weekly cultural tip ⚡️\n\nThe #LuxFilmLab ...       0.0
# 6877  BELGIUM : Lukas Dhont’s ‘Close’ selected as Be...       0.0
# 6878  Just acting 😂 #actress #Oscars2023 #Acting #تم...    0.4404
# 6879  Hy bud! #Oscars2023 I play lot of characters i...    0.4003
#
# [6880 rows x 2 columns]

# %%
df["sentiment"].mean()
# Out:
# 0.3870986046511628
